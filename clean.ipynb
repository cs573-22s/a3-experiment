# %%
import pandas as pd

df1 = pd.read_csv("netflix_code.csv")
df1
# Out:
#            Country  Total Library Size  No. of TV Shows  No. of Movies  Basic  \
# 0        Argentina                4760             3154           1606   3.74
# 1        Australia                6114             4050           2064   7.84
# 2          Austria                5640             3779           1861   9.03
# 3          Belgium                4990             3374           1616  10.16
# 4          Bolivia                4991             3155           1836   7.99
# ..             ...                 ...              ...            ...    ...
# 60         Ukraine                5336             3261           2075   5.64
# 61  United Kingdom                6643             4551           2092   7.91
# 62   United States                5818             3826           1992   8.99
# 63         Uruguay                4989             3154           1835   8.99
# 64       Venezuela                4797             3154           1643   7.99
#
# ...
